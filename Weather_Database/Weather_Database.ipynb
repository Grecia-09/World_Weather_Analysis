# %%
# Import the random and numoy modules.
import pandas as pd
import random
import numpy as np

# %%
import os
import sys

sys.path.append('/Users/insiktuser/Desktop/UCB - Analysis Projects/World_Weather_Analysis')

# %%
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
# Use the citipy module
from citipy import citipy

# %%
# Get the nearest city using the citipy module.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 772

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7650f12deb2595495f603adb12e81d28

# %%
city_url = url + "&q=" + "Denver"
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7650f12deb2595495f603adb12e81d28&q=Denver

# %%
city_weather = requests.get(city_url)
city_weather.status_code
# Out:
# 200

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Denver"
city_weather = requests.get(city_url)
city_weather.json()
# Out:
# {'coord': {'lon': -104.98, 'lat': 39.74},
#  'weather': [{'id': 803,
#    'main': 'Clouds',
#    'description': 'broken clouds',
#    'icon': '04n'}],
#  'base': 'stations',
#  'main': {'temp': 33.03,
#   'feels_like': 18.81,
#   'temp_min': 30.99,
#   'temp_max': 35.01,
#   'pressure': 1015,
#   'humidity': 71},
#  'visibility': 10000,
#  'wind': {'speed': 17.22, 'deg': 360},
#  'clouds': {'all': 75},
#  'dt': 1603601411,
#  'sys': {'type': 1,
#   'id': 3449,
#   'country': 'US',
#   'sunrise': 1603545610,
#   'sunset': 1603584458},
#  'timezone': -21600,
#  'id': 5419384,
#  'name': 'Denver',
#  'cod': 200}

# %%
# Create an empty list to hold the weather data.
new_city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        new_city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | sao filipe
# Processing Record 2 of Set 1 | salta
# Processing Record 3 of Set 1 | vao
# Processing Record 4 of Set 1 | clyde river
# Processing Record 5 of Set 1 | bengkulu
# Processing Record 6 of Set 1 | inta
# Processing Record 7 of Set 1 | avarua
# Processing Record 8 of Set 1 | dolbeau
# City not found. Skipping...
# Processing Record 9 of Set 1 | rikitea
# Processing Record 10 of Set 1 | korla
# Processing Record 11 of Set 1 | georgetown
# Processing Record 12 of Set 1 | asilah
# Processing Record 13 of Set 1 | batouri
# Processing Record 14 of Set 1 | zhigansk
# Processing Record 15 of Set 1 | busselton
# Processing Record 16 of Set 1 | sola
# Processing Record 17 of Set 1 | airai
# Processing Record 18 of Set 1 | krasnoarmeysk
# Processing Record 19 of Set 1 | kodiak
# Processing Record 20 of Set 1 | ushuaia
# Processing Record 21 of Set 1 | atuona
# Processing Record 22 of Set 1 | ngukurr
# City not found. Skipping...
# Processing Record 23 of Set 1 | tarauaca
# Processing Record 24 of Set 1 | virginia beach
# Processing Record 25 of Set 1 | port elizabeth
# Processing Record 26 of Set 1 | cape town
# Processing Record 27 of Set 1 | klaksvik
# Processing Record 28 of Set 1 | jumla
# Processing Record 29 of Set 1 | upernavik
# Processing Record 30 of Set 1 | kizukuri
# Processing Record 31 of Set 1 | new norfolk
# Processing Record 32 of Set 1 | qaanaaq
# Processing Record 33 of Set 1 | mataura
# Processing Record 34 of Set 1 | vila franca do campo
# Processing Record 35 of Set 1 | albany
# Processing Record 36 of Set 1 | garowe
# Processing Record 37 of Set 1 | talnakh
# Processing Record 38 of Set 1 | ostrovnoy
# Processing Record 39 of Set 1 | lolua
# City not found. Skipping...
# Processing Record 40 of Set 1 | dicabisagan
# Processing Record 41 of Set 1 | hilo
# Processing Record 42 of Set 1 | ojinaga
# Processing Record 43 of Set 1 | codrington
# Processing Record 44 of Set 1 | vaini
# Processing Record 45 of Set 1 | banda aceh
# Processing Record 46 of Set 1 | stoyba
# City not found. Skipping...
# Processing Record 47 of Set 1 | puerto ayora
# Processing Record 48 of Set 1 | mangrol
# Processing Record 49 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 50 of Set 1 | kununurra
# Processing Record 1 of Set 2 | nanortalik
# Processing Record 2 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 3 of Set 2 | castro
# Processing Record 4 of Set 2 | tautira
# Processing Record 5 of Set 2 | pevek
# Processing Record 6 of Set 2 | yellowknife
# Processing Record 7 of Set 2 | turbat
# Processing Record 8 of Set 2 | punta arenas
# Processing Record 9 of Set 2 | scottsburgh
# City not found. Skipping...
# Processing Record 10 of Set 2 | los llanos de aridane
# Processing Record 11 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 12 of Set 2 | umaria
# Processing Record 13 of Set 2 | bluff
# Processing Record 14 of Set 2 | manavalakurichi
# Processing Record 15 of Set 2 | chapais
# Processing Record 16 of Set 2 | rio gallegos
# Processing Record 17 of Set 2 | bontang
# Processing Record 18 of Set 2 | hobart
# Processing Record 19 of Set 2 | ornskoldsvik
# Processing Record 20 of Set 2 | barrow
# Processing Record 21 of Set 2 | guerrero negro
# Processing Record 22 of Set 2 | cairns
# Processing Record 23 of Set 2 | puksoozero
# Processing Record 24 of Set 2 | east london
# Processing Record 25 of Set 2 | norman wells
# Processing Record 26 of Set 2 | mabaruma
# Processing Record 27 of Set 2 | depok
# Processing Record 28 of Set 2 | nikolskoye
# Processing Record 29 of Set 2 | tiksi
# Processing Record 30 of Set 2 | petropavlovsk-kamchatskiy
# Processing Record 31 of Set 2 | tual
# Processing Record 32 of Set 2 | storsteinnes
# Processing Record 33 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 34 of Set 2 | ongandjera
# Processing Record 35 of Set 2 | souillac
# Processing Record 36 of Set 2 | arraial do cabo
# Processing Record 37 of Set 2 | cefalu
# Processing Record 38 of Set 2 | carpinteria
# Processing Record 39 of Set 2 | teramo
# Processing Record 40 of Set 2 | carutapera
# Processing Record 41 of Set 2 | makakilo city
# Processing Record 42 of Set 2 | kapaa
# Processing Record 43 of Set 2 | carnarvon
# Processing Record 44 of Set 2 | saint george
# Processing Record 45 of Set 2 | kavieng
# Processing Record 46 of Set 2 | severo-kurilsk
# Processing Record 47 of Set 2 | sorland
# Processing Record 48 of Set 2 | beloha
# Processing Record 49 of Set 2 | chuy
# Processing Record 50 of Set 2 | okhotsk
# Processing Record 1 of Set 3 | itarema
# Processing Record 2 of Set 3 | tura
# Processing Record 3 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 4 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 5 of Set 3 | hobyo
# Processing Record 6 of Set 3 | adelaide
# Processing Record 7 of Set 3 | yairipok
# Processing Record 8 of Set 3 | lorengau
# Processing Record 9 of Set 3 | morros
# Processing Record 10 of Set 3 | saldanha
# Processing Record 11 of Set 3 | ribeira grande
# Processing Record 12 of Set 3 | dzhusaly
# City not found. Skipping...
# Processing Record 13 of Set 3 | san quintin
# Processing Record 14 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 15 of Set 3 | ahipara
# Processing Record 16 of Set 3 | tasiilaq
# Processing Record 17 of Set 3 | port shepstone
# Processing Record 18 of Set 3 | aklavik
# Processing Record 19 of Set 3 | quatre cocos
# Processing Record 20 of Set 3 | kaihua
# Processing Record 21 of Set 3 | kruisfontein
# Processing Record 22 of Set 3 | ponta do sol
# Processing Record 23 of Set 3 | saint-francois
# Processing Record 24 of Set 3 | wladyslawowo
# Processing Record 25 of Set 3 | urdzhar
# City not found. Skipping...
# Processing Record 26 of Set 3 | toora-khem
# Processing Record 27 of Set 3 | mount gambier
# Processing Record 28 of Set 3 | santa maria da boa vista
# Processing Record 29 of Set 3 | torbay
# Processing Record 30 of Set 3 | tiznit
# Processing Record 31 of Set 3 | thompson
# Processing Record 32 of Set 3 | oneonta
# Processing Record 33 of Set 3 | dingle
# Processing Record 34 of Set 3 | phangnga
# Processing Record 35 of Set 3 | provideniya
# Processing Record 36 of Set 3 | whitehorse
# Processing Record 37 of Set 3 | lagoa
# Processing Record 38 of Set 3 | sabha
# Processing Record 39 of Set 3 | brae
# Processing Record 40 of Set 3 | uyskoye
# Processing Record 41 of Set 3 | sambava
# Processing Record 42 of Set 3 | khorixas
# Processing Record 43 of Set 3 | ostersund
# Processing Record 44 of Set 3 | zhezkazgan
# Processing Record 45 of Set 3 | dakar
# Processing Record 46 of Set 3 | lebu
# Processing Record 47 of Set 3 | leningradskiy
# Processing Record 48 of Set 3 | husavik
# Processing Record 49 of Set 3 | zapolyarnyy
# Processing Record 50 of Set 3 | jamestown
# Processing Record 1 of Set 4 | razole
# Processing Record 2 of Set 4 | bose
# Processing Record 3 of Set 4 | karaul
# City not found. Skipping...
# Processing Record 4 of Set 4 | ibra
# Processing Record 5 of Set 4 | seymchan
# Processing Record 6 of Set 4 | luwuk
# Processing Record 7 of Set 4 | bethel
# Processing Record 8 of Set 4 | rehoboth
# Processing Record 9 of Set 4 | flinders
# Processing Record 10 of Set 4 | khatanga
# Processing Record 11 of Set 4 | mahebourg
# Processing Record 12 of Set 4 | lompoc
# Processing Record 13 of Set 4 | peniche
# Processing Record 14 of Set 4 | longyearbyen
# Processing Record 15 of Set 4 | saint-philippe
# Processing Record 16 of Set 4 | roshchino
# Processing Record 17 of Set 4 | san policarpo
# Processing Record 18 of Set 4 | yingkou
# Processing Record 19 of Set 4 | beringovskiy
# Processing Record 20 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 21 of Set 4 | khasan
# Processing Record 22 of Set 4 | srednekolymsk
# Processing Record 23 of Set 4 | port hedland
# Processing Record 24 of Set 4 | kirya
# Processing Record 25 of Set 4 | yartsevo
# Processing Record 26 of Set 4 | hualmay
# Processing Record 27 of Set 4 | san carlos de bariloche
# Processing Record 28 of Set 4 | hermanus
# Processing Record 29 of Set 4 | sinnamary
# Processing Record 30 of Set 4 | rockport
# Processing Record 31 of Set 4 | sandwick
# Processing Record 32 of Set 4 | beyneu
# Processing Record 33 of Set 4 | saskylakh
# Processing Record 34 of Set 4 | cidreira
# Processing Record 35 of Set 4 | huarmey
# Processing Record 36 of Set 4 | alta floresta
# Processing Record 37 of Set 4 | turtas
# Processing Record 38 of Set 4 | karoi
# Processing Record 39 of Set 4 | lavrentiya
# Processing Record 40 of Set 4 | milicz
# Processing Record 41 of Set 4 | sitka
# Processing Record 42 of Set 4 | san cristobal
# Processing Record 43 of Set 4 | novikovo
# Processing Record 44 of Set 4 | marsa matruh
# Processing Record 45 of Set 4 | namibe
# Processing Record 46 of Set 4 | babu
# Processing Record 47 of Set 4 | dawson creek
# Processing Record 48 of Set 4 | aksu
# Processing Record 49 of Set 4 | banmo
# City not found. Skipping...
# Processing Record 50 of Set 4 | kahului
# Processing Record 1 of Set 5 | butaritari
# Processing Record 2 of Set 5 | santa cruz
# Processing Record 3 of Set 5 | catuday
# Processing Record 4 of Set 5 | bambous virieux
# Processing Record 5 of Set 5 | faanui
# Processing Record 6 of Set 5 | cabo san lucas
# Processing Record 7 of Set 5 | dagana
# Processing Record 8 of Set 5 | chuguyevka
# Processing Record 9 of Set 5 | constitucion
# Processing Record 10 of Set 5 | plettenberg bay
# Processing Record 11 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 12 of Set 5 | villacarrillo
# Processing Record 13 of Set 5 | lasa
# Processing Record 14 of Set 5 | pierre
# Processing Record 15 of Set 5 | bom sucesso
# Processing Record 16 of Set 5 | mecca
# Processing Record 17 of Set 5 | dikson
# Processing Record 18 of Set 5 | katsuura
# Processing Record 19 of Set 5 | razvilnoye
# Processing Record 20 of Set 5 | dinghai
# Processing Record 21 of Set 5 | sofiysk
# City not found. Skipping...
# Processing Record 22 of Set 5 | namatanai
# Processing Record 23 of Set 5 | saint-paul
# Processing Record 24 of Set 5 | nizwa
# Processing Record 25 of Set 5 | clonakilty
# Processing Record 26 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 27 of Set 5 | kovylkino
# Processing Record 28 of Set 5 | yulara
# Processing Record 29 of Set 5 | batsfjord
# Processing Record 30 of Set 5 | kaitangata
# Processing Record 31 of Set 5 | kupang
# Processing Record 32 of Set 5 | meulaboh
# Processing Record 33 of Set 5 | taolanaro
# City not found. Skipping...
# Processing Record 34 of Set 5 | anloga
# Processing Record 35 of Set 5 | bayangol
# Processing Record 36 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 37 of Set 5 | bredasdorp
# Processing Record 38 of Set 5 | barra do pirai
# Processing Record 39 of Set 5 | urengoy
# Processing Record 40 of Set 5 | mitu
# Processing Record 41 of Set 5 | moerai
# Processing Record 42 of Set 5 | moranbah
# Processing Record 43 of Set 5 | port alfred
# Processing Record 44 of Set 5 | edson
# Processing Record 45 of Set 5 | sechura
# Processing Record 46 of Set 5 | beira
# Processing Record 47 of Set 5 | kazachinskoye
# Processing Record 48 of Set 5 | kenai
# Processing Record 49 of Set 5 | fort nelson
# Processing Record 50 of Set 5 | chebsara
# Processing Record 1 of Set 6 | cayenne
# Processing Record 2 of Set 6 | shirokiy
# Processing Record 3 of Set 6 | katherine
# Processing Record 4 of Set 6 | kyabe
# Processing Record 5 of Set 6 | vila velha
# Processing Record 6 of Set 6 | hamilton
# Processing Record 7 of Set 6 | ternate
# Processing Record 8 of Set 6 | adrar
# Processing Record 9 of Set 6 | ossora
# Processing Record 10 of Set 6 | kutum
# Processing Record 11 of Set 6 | trinidad
# Processing Record 12 of Set 6 | victoria
# Processing Record 13 of Set 6 | alofi
# Processing Record 14 of Set 6 | hasaki
# Processing Record 15 of Set 6 | kunda
# Processing Record 16 of Set 6 | nanakuli
# Processing Record 17 of Set 6 | manikpur
# Processing Record 18 of Set 6 | luganville
# Processing Record 19 of Set 6 | jizan
# Processing Record 20 of Set 6 | dudinka
# Processing Record 21 of Set 6 | san borja
# Processing Record 22 of Set 6 | keuruu
# Processing Record 23 of Set 6 | kushmurun
# Processing Record 24 of Set 6 | verkhnevilyuysk
# Processing Record 25 of Set 6 | sisimiut
# Processing Record 26 of Set 6 | copiague
# Processing Record 27 of Set 6 | college
# Processing Record 28 of Set 6 | kavarna
# Processing Record 29 of Set 6 | paamiut
# Processing Record 30 of Set 6 | chokurdakh
# Processing Record 31 of Set 6 | nantucket
# Processing Record 32 of Set 6 | jacobabad
# Processing Record 33 of Set 6 | ponta delgada
# Processing Record 34 of Set 6 | wanning
# Processing Record 35 of Set 6 | pyaozerskiy
# Processing Record 36 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 37 of Set 6 | mar del plata
# Processing Record 38 of Set 6 | mayahi
# Processing Record 39 of Set 6 | luderitz
# Processing Record 40 of Set 6 | kabalo
# Processing Record 41 of Set 6 | iqaluit
# Processing Record 42 of Set 6 | yelizavetino
# Processing Record 43 of Set 6 | dieppe bay
# City not found. Skipping...
# Processing Record 44 of Set 6 | pytalovo
# Processing Record 45 of Set 6 | kandrian
# Processing Record 46 of Set 6 | khargone
# Processing Record 47 of Set 6 | sarankhola
# Processing Record 48 of Set 6 | vilhena
# Processing Record 49 of Set 6 | naze
# Processing Record 50 of Set 6 | cherskiy
# Processing Record 1 of Set 7 | dekar
# Processing Record 2 of Set 7 | maltahohe
# Processing Record 3 of Set 7 | mvuma
# Processing Record 4 of Set 7 | san martin
# Processing Record 5 of Set 7 | kanker
# Processing Record 6 of Set 7 | miri
# Processing Record 7 of Set 7 | ha giang
# Processing Record 8 of Set 7 | dipkarpaz
# City not found. Skipping...
# Processing Record 9 of Set 7 | berbera
# Processing Record 10 of Set 7 | grindavik
# Processing Record 11 of Set 7 | tezu
# Processing Record 12 of Set 7 | ust-kuyga
# Processing Record 13 of Set 7 | meyungs
# City not found. Skipping...
# Processing Record 14 of Set 7 | shache
# Processing Record 15 of Set 7 | xuddur
# Processing Record 16 of Set 7 | champerico
# Processing Record 17 of Set 7 | hunza
# City not found. Skipping...
# Processing Record 18 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 19 of Set 7 | zarichne
# Processing Record 20 of Set 7 | nishihara
# Processing Record 21 of Set 7 | manali
# Processing Record 22 of Set 7 | warqla
# City not found. Skipping...
# Processing Record 23 of Set 7 | malanje
# Processing Record 24 of Set 7 | bol
# Processing Record 25 of Set 7 | shimanovsk
# Processing Record 26 of Set 7 | tommot
# Processing Record 27 of Set 7 | bilibino
# Processing Record 28 of Set 7 | dunedin
# Processing Record 29 of Set 7 | lhuntshi
# City not found. Skipping...
# Processing Record 30 of Set 7 | tuktoyaktuk
# Processing Record 31 of Set 7 | tuatapere
# Processing Record 32 of Set 7 | rettikhovka
# Processing Record 33 of Set 7 | znamenskoye
# Processing Record 34 of Set 7 | faya
# Processing Record 35 of Set 7 | yeniseysk
# Processing Record 36 of Set 7 | pringsewu
# Processing Record 37 of Set 7 | lata
# Processing Record 38 of Set 7 | chipata
# Processing Record 39 of Set 7 | wasco
# Processing Record 40 of Set 7 | arlit
# Processing Record 41 of Set 7 | cherdyn
# Processing Record 42 of Set 7 | praia da vitoria
# Processing Record 43 of Set 7 | pisco
# Processing Record 44 of Set 7 | teya
# Processing Record 45 of Set 7 | hihifo
# City not found. Skipping...
# Processing Record 46 of Set 7 | ambilobe
# Processing Record 47 of Set 7 | yar-sale
# Processing Record 48 of Set 7 | smithers
# Processing Record 49 of Set 7 | conde
# Processing Record 50 of Set 7 | hithadhoo
# Processing Record 1 of Set 8 | portland
# Processing Record 2 of Set 8 | tucuman
# Processing Record 3 of Set 8 | orbetello
# Processing Record 4 of Set 8 | havre-saint-pierre
# Processing Record 5 of Set 8 | palmas bellas
# Processing Record 6 of Set 8 | abrau-dyurso
# Processing Record 7 of Set 8 | malwan
# City not found. Skipping...
# Processing Record 8 of Set 8 | grudziadz
# Processing Record 9 of Set 8 | norilsk
# Processing Record 10 of Set 8 | erenhot
# Processing Record 11 of Set 8 | lubango
# Processing Record 12 of Set 8 | sept-iles
# Processing Record 13 of Set 8 | fort saint john
# City not found. Skipping...
# Processing Record 14 of Set 8 | kloulklubed
# Processing Record 15 of Set 8 | olafsvik
# Processing Record 16 of Set 8 | bonito
# Processing Record 17 of Set 8 | mkokotoni
# Processing Record 18 of Set 8 | namie
# Processing Record 19 of Set 8 | opuwo
# Processing Record 20 of Set 8 | playas
# Processing Record 21 of Set 8 | ios
# Processing Record 22 of Set 8 | dauphin
# Processing Record 23 of Set 8 | mastic beach
# Processing Record 24 of Set 8 | nan
# Processing Record 25 of Set 8 | sabzevar
# Processing Record 26 of Set 8 | qarqin
# Processing Record 27 of Set 8 | roald
# Processing Record 28 of Set 8 | nola
# Processing Record 29 of Set 8 | port macquarie
# Processing Record 30 of Set 8 | portobelo
# Processing Record 31 of Set 8 | te anau
# Processing Record 32 of Set 8 | guasdualito
# Processing Record 33 of Set 8 | veraval
# Processing Record 34 of Set 8 | aragats
# Processing Record 35 of Set 8 | shimoda
# Processing Record 36 of Set 8 | gushikawa
# Processing Record 37 of Set 8 | mandalay
# Processing Record 38 of Set 8 | guiglo
# Processing Record 39 of Set 8 | mount isa
# Processing Record 40 of Set 8 | otjiwarongo
# Processing Record 41 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 42 of Set 8 | bud
# Processing Record 43 of Set 8 | maniitsoq
# Processing Record 44 of Set 8 | urucui
# Processing Record 45 of Set 8 | noumea
# Processing Record 46 of Set 8 | wysokie mazowieckie
# Processing Record 47 of Set 8 | synya
# Processing Record 48 of Set 8 | valparaiso
# Processing Record 49 of Set 8 | coralville
# Processing Record 50 of Set 8 | houston
# Processing Record 1 of Set 9 | slave lake
# Processing Record 2 of Set 9 | kargasok
# Processing Record 3 of Set 9 | morondava
# Processing Record 4 of Set 9 | tequixquitla
# Processing Record 5 of Set 9 | ancud
# Processing Record 6 of Set 9 | saint-pierre
# Processing Record 7 of Set 9 | batemans bay
# Processing Record 8 of Set 9 | poronaysk
# Processing Record 9 of Set 9 | inuvik
# Processing Record 10 of Set 9 | esperance
# Processing Record 11 of Set 9 | port blair
# Processing Record 12 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 13 of Set 9 | komsomolskiy
# Processing Record 14 of Set 9 | ijaki
# City not found. Skipping...
# Processing Record 15 of Set 9 | narasannapeta
# Processing Record 16 of Set 9 | oranjestad
# Processing Record 17 of Set 9 | ginda
# Processing Record 18 of Set 9 | macamic
# Processing Record 19 of Set 9 | umm lajj
# Processing Record 20 of Set 9 | nuevo san juan parangaricutiro
# Processing Record 21 of Set 9 | solnechnyy
# Processing Record 22 of Set 9 | fare
# Processing Record 23 of Set 9 | mogadishu
# Processing Record 24 of Set 9 | nuuk
# Processing Record 25 of Set 9 | goderich
# Processing Record 26 of Set 9 | salalah
# Processing Record 27 of Set 9 | novato
# Processing Record 28 of Set 9 | laguna
# Processing Record 29 of Set 9 | madaripur
# Processing Record 30 of Set 9 | felanitx
# Processing Record 31 of Set 9 | ileza
# Processing Record 32 of Set 9 | qaqortoq
# Processing Record 33 of Set 9 | emba
# Processing Record 34 of Set 9 | avera
# Processing Record 35 of Set 9 | bumba
# Processing Record 36 of Set 9 | teahupoo
# Processing Record 37 of Set 9 | asyut
# Processing Record 38 of Set 9 | fortuna
# Processing Record 39 of Set 9 | timizart
# Processing Record 40 of Set 9 | batagay-alyta
# Processing Record 41 of Set 9 | inhambane
# Processing Record 42 of Set 9 | del rio
# Processing Record 43 of Set 9 | ati
# Processing Record 44 of Set 9 | nueve de julio
# Processing Record 45 of Set 9 | benghazi
# Processing Record 46 of Set 9 | robertsport
# Processing Record 47 of Set 9 | stokmarknes
# Processing Record 48 of Set 9 | khani
# Processing Record 49 of Set 9 | jalu
# Processing Record 50 of Set 9 | penzance
# Processing Record 1 of Set 10 | tayu
# Processing Record 2 of Set 10 | lanzhou
# Processing Record 3 of Set 10 | nabire
# Processing Record 4 of Set 10 | cabra
# Processing Record 5 of Set 10 | auki
# Processing Record 6 of Set 10 | dunapataj
# Processing Record 7 of Set 10 | ankang
# Processing Record 8 of Set 10 | ammapettai
# Processing Record 9 of Set 10 | mutoko
# Processing Record 10 of Set 10 | yambio
# Processing Record 11 of Set 10 | costeiu
# Processing Record 12 of Set 10 | qandala
# Processing Record 13 of Set 10 | ginir
# Processing Record 14 of Set 10 | kirensk
# Processing Record 15 of Set 10 | phan rang
# City not found. Skipping...
# Processing Record 16 of Set 10 | ketchikan
# Processing Record 17 of Set 10 | acapulco
# Processing Record 18 of Set 10 | boa vista
# Processing Record 19 of Set 10 | ende
# Processing Record 20 of Set 10 | battle creek
# Processing Record 21 of Set 10 | kashi
# Processing Record 22 of Set 10 | magistralnyy
# Processing Record 23 of Set 10 | turtkul
# City not found. Skipping...
# Processing Record 24 of Set 10 | khorol
# Processing Record 25 of Set 10 | san carlos
# Processing Record 26 of Set 10 | bubaque
# Processing Record 27 of Set 10 | ust-barguzin
# Processing Record 28 of Set 10 | amderma
# City not found. Skipping...
# Processing Record 29 of Set 10 | outjo
# Processing Record 30 of Set 10 | tabas
# Processing Record 31 of Set 10 | port lincoln
# Processing Record 32 of Set 10 | vozhega
# Processing Record 33 of Set 10 | taoudenni
# Processing Record 34 of Set 10 | xapuri
# Processing Record 35 of Set 10 | biak
# Processing Record 36 of Set 10 | hede
# Processing Record 37 of Set 10 | gaomi
# Processing Record 38 of Set 10 | truro
# Processing Record 39 of Set 10 | coihaique
# Processing Record 40 of Set 10 | yirol
# City not found. Skipping...
# Processing Record 41 of Set 10 | mahibadhoo
# Processing Record 42 of Set 10 | karratha
# Processing Record 43 of Set 10 | treinta y tres
# Processing Record 44 of Set 10 | santa vitoria do palmar
# Processing Record 45 of Set 10 | tiarei
# Processing Record 46 of Set 10 | mrirt
# City not found. Skipping...
# Processing Record 47 of Set 10 | samusu
# City not found. Skipping...
# Processing Record 48 of Set 10 | sao sebastiao
# Processing Record 49 of Set 10 | port keats
# Processing Record 50 of Set 10 | gisborne
# Processing Record 1 of Set 11 | ondorhaan
# City not found. Skipping...
# Processing Record 2 of Set 11 | la ronge
# Processing Record 3 of Set 11 | burnie
# Processing Record 4 of Set 11 | ilulissat
# Processing Record 5 of Set 11 | kidal
# Processing Record 6 of Set 11 | poum
# Processing Record 7 of Set 11 | savonlinna
# Processing Record 8 of Set 11 | coremas
# Processing Record 9 of Set 11 | geraldton
# Processing Record 10 of Set 11 | karakendzha
# City not found. Skipping...
# Processing Record 11 of Set 11 | burica
# City not found. Skipping...
# Processing Record 12 of Set 11 | male
# Processing Record 13 of Set 11 | grand centre
# City not found. Skipping...
# Processing Record 14 of Set 11 | alyangula
# Processing Record 15 of Set 11 | palana
# Processing Record 16 of Set 11 | viligili
# City not found. Skipping...
# Processing Record 17 of Set 11 | menomonie
# Processing Record 18 of Set 11 | muli
# Processing Record 19 of Set 11 | antofagasta
# Processing Record 20 of Set 11 | san juan
# Processing Record 21 of Set 11 | jaque
# Processing Record 22 of Set 11 | alotau
# City not found. Skipping...
# Processing Record 23 of Set 11 | sao joao da barra
# Processing Record 24 of Set 11 | narsaq
# Processing Record 25 of Set 11 | huinan
# Processing Record 26 of Set 11 | jackson
# Processing Record 27 of Set 11 | praya
# Processing Record 28 of Set 11 | imbituba
# Processing Record 29 of Set 11 | belaya gora
# Processing Record 30 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 31 of Set 11 | montepuez
# Processing Record 32 of Set 11 | port-gentil
# Processing Record 33 of Set 11 | wadena
# Processing Record 34 of Set 11 | pueblo nuevo
# Processing Record 35 of Set 11 | aykhal
# Processing Record 36 of Set 11 | halifax
# Processing Record 37 of Set 11 | kobryn
# Processing Record 38 of Set 11 | yerofey pavlovich
# Processing Record 39 of Set 11 | mamallapuram
# Processing Record 40 of Set 11 | zarubino
# Processing Record 41 of Set 11 | gamba
# Processing Record 42 of Set 11 | khowai
# Processing Record 43 of Set 11 | kotido
# Processing Record 44 of Set 11 | kuraymah
# Processing Record 45 of Set 11 | tabiauea
# City not found. Skipping...
# Processing Record 46 of Set 11 | xiuyan
# Processing Record 47 of Set 11 | singapore
# Processing Record 48 of Set 11 | coronado
# Processing Record 49 of Set 11 | esqueda
# Processing Record 50 of Set 11 | okandja
# City not found. Skipping...
# Processing Record 1 of Set 12 | henties bay
# Processing Record 2 of Set 12 | inirida
# Processing Record 3 of Set 12 | palmer
# Processing Record 4 of Set 12 | camacha
# Processing Record 5 of Set 12 | minot
# Processing Record 6 of Set 12 | shitanjing
# Processing Record 7 of Set 12 | heilbron
# Processing Record 8 of Set 12 | port moresby
# Processing Record 9 of Set 12 | smoky lake
# Processing Record 10 of Set 12 | baker city
# Processing Record 11 of Set 12 | dhangadhi
# Processing Record 12 of Set 12 | chom bung
# City not found. Skipping...
# Processing Record 13 of Set 12 | pital
# Processing Record 14 of Set 12 | zharkent
# Processing Record 15 of Set 12 | tessalit
# Processing Record 16 of Set 12 | maridi
# Processing Record 17 of Set 12 | yamada
# Processing Record 18 of Set 12 | coahuayana
# Processing Record 19 of Set 12 | buala
# Processing Record 20 of Set 12 | freire
# Processing Record 21 of Set 12 | athabasca
# Processing Record 22 of Set 12 | bereslavka
# Processing Record 23 of Set 12 | necochea
# Processing Record 24 of Set 12 | alice springs
# Processing Record 25 of Set 12 | chagda
# City not found. Skipping...
# Processing Record 26 of Set 12 | aflu
# City not found. Skipping...
# Processing Record 27 of Set 12 | camacari
# Processing Record 28 of Set 12 | togur
# Processing Record 29 of Set 12 | naryan-mar
# Processing Record 30 of Set 12 | ranong
# Processing Record 31 of Set 12 | petatlan
# Processing Record 32 of Set 12 | hailar
# Processing Record 33 of Set 12 | graaff-reinet
# Processing Record 34 of Set 12 | coquimbo
# Processing Record 35 of Set 12 | maceio
# Processing Record 36 of Set 12 | puerto madero
# Processing Record 37 of Set 12 | kaspiyskiy
# Processing Record 38 of Set 12 | caxito
# Processing Record 39 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 40 of Set 12 | springe
# Processing Record 41 of Set 12 | kedrovyy
# Processing Record 42 of Set 12 | tabuk
# Processing Record 43 of Set 12 | cockburn town
# Processing Record 44 of Set 12 | westport
# Processing Record 45 of Set 12 | kitui
# Processing Record 46 of Set 12 | aksarka
# Processing Record 47 of Set 12 | lazaro cardenas
# Processing Record 48 of Set 12 | samalaeulu
# City not found. Skipping...
# Processing Record 49 of Set 12 | filingue
# Processing Record 50 of Set 12 | sao paulo de olivenca
# Processing Record 1 of Set 13 | aripuana
# Processing Record 2 of Set 13 | pozo colorado
# Processing Record 3 of Set 13 | asau
# Processing Record 4 of Set 13 | harper
# Processing Record 5 of Set 13 | orotukan
# Processing Record 6 of Set 13 | zhoucheng
# Processing Record 7 of Set 13 | dharchula
# Processing Record 8 of Set 13 | billings
# Processing Record 9 of Set 13 | andarab
# City not found. Skipping...
# Processing Record 10 of Set 13 | isla vista
# Processing Record 11 of Set 13 | tumannyy
# City not found. Skipping...
# Processing Record 12 of Set 13 | san patricio
# Processing Record 13 of Set 13 | chaa-khol
# City not found. Skipping...
# Processing Record 14 of Set 13 | aviles
# Processing Record 15 of Set 13 | umba
# Processing Record 16 of Set 13 | lillooet
# Processing Record 17 of Set 13 | rey bouba
# Processing Record 18 of Set 13 | ialibu
# Processing Record 19 of Set 13 | oltedal
# Processing Record 20 of Set 13 | pitanga
# Processing Record 21 of Set 13 | moose factory
# Processing Record 22 of Set 13 | maumere
# Processing Record 23 of Set 13 | melendugno
# Processing Record 24 of Set 13 | mandal
# Processing Record 25 of Set 13 | baker
# Processing Record 26 of Set 13 | dzaoudzi
# Processing Record 27 of Set 13 | omsukchan
# Processing Record 28 of Set 13 | noshiro
# Processing Record 29 of Set 13 | aswan
# Processing Record 30 of Set 13 | hami
# Processing Record 31 of Set 13 | saint anthony
# Processing Record 32 of Set 13 | rawson
# Processing Record 33 of Set 13 | umea
# Processing Record 34 of Set 13 | sobolevo
# Processing Record 35 of Set 13 | kavaratti
# Processing Record 36 of Set 13 | shibetsu
# Processing Record 37 of Set 13 | nyurba
# Processing Record 38 of Set 13 | qujing
# Processing Record 39 of Set 13 | da nang
# Processing Record 40 of Set 13 | serabu
# Processing Record 41 of Set 13 | ucluelet
# Processing Record 42 of Set 13 | iquique
# Processing Record 43 of Set 13 | unity
# Processing Record 44 of Set 13 | palu
# Processing Record 45 of Set 13 | george
# Processing Record 46 of Set 13 | cabedelo
# Processing Record 47 of Set 13 | haines junction
# Processing Record 48 of Set 13 | turinsk
# Processing Record 49 of Set 13 | mayskiy
# Processing Record 50 of Set 13 | ntungamo
# Processing Record 1 of Set 14 | kouango
# Processing Record 2 of Set 14 | krasnokamensk
# Processing Record 3 of Set 14 | birao
# Processing Record 4 of Set 14 | itupiranga
# Processing Record 5 of Set 14 | bayshore gardens
# Processing Record 6 of Set 14 | bundaberg
# Processing Record 7 of Set 14 | linhares
# Processing Record 8 of Set 14 | faranah
# Processing Record 9 of Set 14 | yuanping
# Processing Record 10 of Set 14 | aguilas
# Processing Record 11 of Set 14 | ahuimanu
# Processing Record 12 of Set 14 | develi
# Processing Record 13 of Set 14 | andenes
# Processing Record 14 of Set 14 | bulgan
# Processing Record 15 of Set 14 | bandarbeyla
# Processing Record 16 of Set 14 | muros
# Processing Record 17 of Set 14 | bosaso
# Processing Record 18 of Set 14 | barkhan
# Processing Record 19 of Set 14 | salumbar
# Processing Record 20 of Set 14 | mandalgovi
# Processing Record 21 of Set 14 | blythe
# Processing Record 22 of Set 14 | xochihuehuetlan
# Processing Record 23 of Set 14 | sal rei
# Processing Record 24 of Set 14 | atar
# Processing Record 25 of Set 14 | frunze
# Processing Record 26 of Set 14 | vardo
# Processing Record 27 of Set 14 | tir pol
# City not found. Skipping...
# Processing Record 28 of Set 14 | yarqa
# Processing Record 29 of Set 14 | thinadhoo
# Processing Record 30 of Set 14 | betul
# Processing Record 31 of Set 14 | vestmannaeyjar
# Processing Record 32 of Set 14 | karnobat
# Processing Record 33 of Set 14 | dalby
# Processing Record 34 of Set 14 | karlstad
# Processing Record 35 of Set 14 | sibu
# Processing Record 36 of Set 14 | troitskoye
# Processing Record 37 of Set 14 | carballo
# Processing Record 38 of Set 14 | ugoofaaru
# Processing Record 39 of Set 14 | yeletskiy
# City not found. Skipping...
# Processing Record 40 of Set 14 | bereda
# Processing Record 41 of Set 14 | sao jose da coroa grande
# Processing Record 42 of Set 14 | zeya
# Processing Record 43 of Set 14 | manaus
# Processing Record 44 of Set 14 | marzuq
# Processing Record 45 of Set 14 | bathsheba
# Processing Record 46 of Set 14 | bur gabo
# City not found. Skipping...
# Processing Record 47 of Set 14 | touros
# Processing Record 48 of Set 14 | balakhninskiy
# Processing Record 49 of Set 14 | skelleftea
# Processing Record 50 of Set 14 | chipinge
# Processing Record 1 of Set 15 | santiago del estero
# Processing Record 2 of Set 15 | libertad
# Processing Record 3 of Set 15 | summerside
# Processing Record 4 of Set 15 | tornio
# Processing Record 5 of Set 15 | sturgeon bay
# Processing Record 6 of Set 15 | hambantota
# Processing Record 7 of Set 15 | koshurnikovo
# Processing Record 8 of Set 15 | sakakah
# Processing Record 9 of Set 15 | surami
# Processing Record 10 of Set 15 | bilma
# Processing Record 11 of Set 15 | awbari
# Processing Record 12 of Set 15 | raudeberg
# Processing Record 13 of Set 15 | coihueco
# Processing Record 14 of Set 15 | santa ines
# Processing Record 15 of Set 15 | ozernovskiy
# Processing Record 16 of Set 15 | laem sing
# Processing Record 17 of Set 15 | port hardy
# Processing Record 18 of Set 15 | kristiinankaupunki
# Processing Record 19 of Set 15 | wanaka
# Processing Record 20 of Set 15 | louis trichardt
# Processing Record 21 of Set 15 | honiara
# Processing Record 22 of Set 15 | toliary
# City not found. Skipping...
# Processing Record 23 of Set 15 | saint-joseph
# Processing Record 24 of Set 15 | iralaya
# Processing Record 25 of Set 15 | muroto
# Processing Record 26 of Set 15 | paungde
# Processing Record 27 of Set 15 | labuhan
# Processing Record 28 of Set 15 | tawkar
# City not found. Skipping...
# Processing Record 29 of Set 15 | corner brook
# Processing Record 30 of Set 15 | brownsville
# Processing Record 31 of Set 15 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 32 of Set 15 | mackenzie
# Processing Record 33 of Set 15 | broken hill
# Processing Record 34 of Set 15 | pocone
# Processing Record 35 of Set 15 | gazni
# City not found. Skipping...
# Processing Record 36 of Set 15 | atambua
# Processing Record 37 of Set 15 | ryotsu
# Processing Record 38 of Set 15 | turayf
# Processing Record 39 of Set 15 | najran
# Processing Record 40 of Set 15 | olinda
# Processing Record 41 of Set 15 | igarka
# Processing Record 42 of Set 15 | pacific grove
# Processing Record 43 of Set 15 | sinnar
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
new_city_data_df = pd.DataFrame (new_city_data)
new_city_data_df.head(10)
# Out:
#           City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   Sao Filipe  14.90  -24.50     80.47        73         100        9.80
# 1        Salta -24.79  -65.41     73.40        69          40        3.36
# 2          Vao -22.67  167.48     73.38        82          63       18.54
# 3  Clyde River  70.47  -68.59     17.60        78          75       16.11
# 4     Bengkulu  -3.80  102.27     84.15        67          99        5.82
# 5         Inta  66.03   60.17     22.86        92         100       11.07
# 6       Avarua -21.21 -159.78     75.20        73          56       12.75
# 7      Rikitea -23.12 -134.97     74.93        83          98       19.71
# 8        Korla  41.76   86.15     56.10        36           0       12.64
# 9   Georgetown   5.41  100.34     84.20        79          40        6.93
#
#   Country       Description
# 0      CV   overcast clouds
# 1      AR  scattered clouds
# 2      NC     broken clouds
# 3      CA     broken clouds
# 4      ID   overcast clouds
# 5      RU   overcast clouds
# 6      CK     broken clouds
# 7      PF        light rain
# 8      CN         clear sky
# 9      MY  scattered clouds

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Description"]
new_city_data_df = new_city_data_df[new_column_order]
new_city_data_df.head(10)
# Out:
#           City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0   Sao Filipe      CV  14.90  -24.50     80.47        73         100
# 1        Salta      AR -24.79  -65.41     73.40        69          40
# 2          Vao      NC -22.67  167.48     73.38        82          63
# 3  Clyde River      CA  70.47  -68.59     17.60        78          75
# 4     Bengkulu      ID  -3.80  102.27     84.15        67          99
# 5         Inta      RU  66.03   60.17     22.86        92         100
# 6       Avarua      CK -21.21 -159.78     75.20        73          56
# 7      Rikitea      PF -23.12 -134.97     74.93        83          98
# 8        Korla      CN  41.76   86.15     56.10        36           0
# 9   Georgetown      MY   5.41  100.34     84.20        79          40
#
#    Wind Speed       Description
# 0        9.80   overcast clouds
# 1        3.36  scattered clouds
# 2       18.54     broken clouds
# 3       16.11     broken clouds
# 4        5.82   overcast clouds
# 5       11.07   overcast clouds
# 6       12.75     broken clouds
# 7       19.71        light rain
# 8       12.64         clear sky
# 9        6.93  scattered clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
new_city_data_df.to_csv(output_data_file, index_label="City_ID")
